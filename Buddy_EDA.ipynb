# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
bom_movie_gross = pd.read_csv("../data/bom.movie_gross.csv.gz")

# %%
imdb_name_basics = pd.read_csv("../data/imdb.name.basics.csv.gz")

# %%
imdb_title_akas = pd.read_csv("../data/imdb.title.akas.csv.gz")

# %%
imdb_title_basics = pd.read_csv("../data/imdb.title.basics.csv.gz")

# %%
imdb_title_crew = pd.read_csv("../data/imdb.title.crew.csv.gz")

# %%
imdb_title_principals = pd.read_csv("../data/imdb.title.principals.csv.gz")

# %%
imdb_title_ratings = pd.read_csv("../data/imdb.title.ratings.csv.gz")

# %%
rt_movie_info = pd.read_csv("../data/rt.movie_info.tsv.gz", sep='\t')

# %%
# rt_reviews = pd.read_csv(data_directory+'rt.reviews.tsv.gz', delimiter = '\t', encoding = 'cp437')

# %%
tmdb_movies = pd.read_csv("../data/tmdb.movies.csv.gz")

# %%
tn_movie_budgets = pd.read_csv("../data/tn.movie_budgets.csv.gz")

# %%
# %matplotlib inline

# %%
import pandas as pd
data_directory = '../Data/'  
# df_bom = pd.read_csv(data_directory+'bom.movie_gross.csv.gz') #Source: Box Office Mojo
# df_rt_movies = pd.read_csv(data_directory+'rt.movie_info.tsv.gz', delimiter = '\t') #Source: Rotten tomatoes
# df_rt_reviews = pd.read_csv(data_directory+'rt.reviews.tsv.gz', delimiter = '\t', encoding = 'cp437') #Source: Rotten tomatoes 
df_imdb_basics = pd.read_csv(data_directory+'imdb.title.basics.csv.gz') # Source: IMDB
df_imdb_ratings = pd.read_csv(data_directory+'imdb.title.ratings.csv.gz') # Source: IMDB
df_mdb_ratings = pd.read_csv(data_directory+'tmdb.movies.csv.gz') # Source: MovieDB
df_mdb_revenues = pd.read_csv(data_directory+'tn.movie_budgets.csv.gz') # Source: MovieDB

# %%
imdb_name_basics.loc[imdb_name_basics["primary_name"] == "Joseph Gordon-Levitt"]
# Out:
#          nconst          primary_name  birth_year  death_year  \
# 4260  nm0330687  Joseph Gordon-Levitt      1981.0         NaN
#
#              primary_profession                         known_for_titles
# 4260  actor,producer,soundtrack  tt1375666,tt1276104,tt1306980,tt2229499

# %%
imdb_title_ratings.loc[imdb_title_ratings["tconst"] == "tt1375666"]
# Out:
#           tconst  averagerating  numvotes
# 63498  tt1375666            8.8   1841066

# %% [markdown]
# # Creating Lists and Graphs and Things

# %% [markdown]
# Instead of using the arbitrary 100000 we will use 25%...

# %% [markdown]
# So I want to first sort by "averagerating", because if we're going to claim to know what type of movie Microsoft Film Studios should make like some kind of mystic, we may as tell them we aim to be compared to the best of the best.  But they also need to have a certain amount of weight, or proof which comes for better or worse throgh "numvotes", because strength in numbers.

# %% [markdown]
# # Plot average rating over the y-axis, movies with greater "numvotes" have a more opaque color whereas the movies with less are transparent. X-Axis displays names? vvvv

# %%
# The function cleans the two Movie DB dataframes
def df_clean(data_frame, release_date_column, movie_title_column):
    data_frame.drop_duplicates(keep = 'first', inplace = True)
    if data_frame[release_date_column].dtypes == 'int64':
        data_frame[release_date_column] = pd.to_datetime(data_frame[release_date_column], format = '%Y').dt.to_period("Y") # Assume that movies released in the same month of the same year are the same.
    else:
        data_frame[release_date_column] = pd.to_datetime(data_frame[release_date_column]).dt.to_period("Y") # Assume that movies released in the same month of the same year are the same.
    data_frame[movie_title_column] = [" ".join(title.upper().split()) for title in data_frame[movie_title_column]] # Remove whitespaces
    data_frame[movie_title_column] = [title.replace('Â', "'") for title in data_frame[movie_title_column]] 
    data_frame[movie_title_column] = [title.replace('#', '') for title in data_frame[movie_title_column]] 
    data_frame[movie_title_column] = [title.replace('"', '') for title in data_frame[movie_title_column]]               
    data_frame.drop_duplicates([movie_title_column, release_date_column], keep = False, inplace = True)
    data_frame.sort_values(by = [release_date_column, movie_title_column], ascending = [False, True], inplace = True)
    data_frame.rename(columns={release_date_column: 'release_date', movie_title_column: 'title'}, inplace = True)
    return data_frame

# %%
# Merge Movie DB dataframes
df_mdb_ratings.drop('Unnamed: 0', axis = 1, inplace = True) # This is an extra index column
df_mdb_ratings = df_clean(df_mdb_ratings, 'release_date', 'title')
df_mdb_revenues = df_clean(df_mdb_revenues, 'release_date', 'movie')
df_mdb = pd.merge(df_mdb_ratings, df_mdb_revenues, how = 'outer', \
              left_on = ['title', 'release_date'], \
              right_on = ['title', 'release_date'], \
              indicator = True, validate="one_to_one", \
              sort = True)

# %%
# Merge IMDB dataframes
df_imdb_basics = df_clean(df_imdb_basics, 'start_year', 'primary_title')
df_imdb = pd.merge(df_imdb_basics, df_imdb_ratings, how = 'outer', \
              on = 'tconst', \
              indicator = True, validate="one_to_one")

# %%
# Merge Movie DB and IMDB dataframes
df = pd.merge(df_imdb.drop(columns = '_merge'), df_mdb.drop(columns = '_merge'), how = 'outer', \
              left_on = ['title', 'release_date'], \
              right_on = ['title', 'release_date'], \
              indicator = True, validate="many_to_one", \
              sort = True)
df_merged = df.loc[df._merge == 'both']

# %%
df_merged = df.loc[df._merge == 'both']

# %% [markdown]
# # Took out any movies that didn't have rating votes in either IMDB or MoviesDB

# %%
df_clean = pd.read_csv("export_df_clean.csv")

# %%
df_clean.columns
# Out:
# Index(['title', 'release_year', 'genres', 'averagerating', 'numvotes',
#        'genre_ids', 'popularity', 'vote_average', 'vote_count',
#        'release_year_month', 'production_budget', 'domestic_gross',
#        'worldwide_gross', '_merge'],
#       dtype='object')

# %%
# df_clean["release_year_month"].map(lambda x: len(x.split())).head()

month = []
for movies in df_clean["release_year_month"]:
    if isinstance(movies, str):
        month.append(movies[5:7])
    else:
        month.append("00")
df_clean["month"] = month

# %%
df_clean.describe()
# Out:
#        release_year  averagerating      numvotes    popularity  vote_average  \
# count  85455.000000   73941.000000  7.394100e+04  25299.000000  25299.000000
# mean    2014.173401       6.331804  3.571793e+03      3.044182      5.979371
# std        2.930876       1.475130  3.059231e+04      4.264437      1.865593
# min     1930.000000       1.000000  5.000000e+00      0.600000      0.000000
# 25%     2012.000000       5.500000  1.400000e+01      0.600000      5.000000
# 50%     2014.000000       6.500000  4.900000e+01      1.322000      6.000000
# 75%     2016.000000       7.400000  2.840000e+02      3.491000      7.000000
# max     2020.000000      10.000000  1.841066e+06     80.773000     10.000000
#
#          vote_count
# count  25299.000000
# mean     178.572750
# std      913.083646
# min        1.000000
# 25%        1.000000
# 50%        5.000000
# 75%       25.000000
# max    22186.000000

# %%
df_watched = df_clean.loc[(df_clean["numvotes"] >= 284) & (df_clean["vote_count"] >= 25)]
#Removed all but the top 25% of voted on movies...

# %%
df_watched.columns
# Out:
# Index(['title', 'release_year', 'genres', 'averagerating', 'numvotes',
#        'genre_ids', 'popularity', 'vote_average', 'vote_count',
#        'release_year_month', 'production_budget', 'domestic_gross',
#        'worldwide_gross', '_merge', 'month'],
#       dtype='object')

# %%
df_watched_year = df_clean.loc[(df_clean["release_year"] >= 2010)]

# %%
sum(df_watched_year["release_year"] == 2019)
#2010 7992
#2011 8721
#2012 8920
#2013 9443
#2014 9756
#2015 9820
#2016 9929
#2017 9955
#2018 8501
# Out:
# 2208

# %%
total_movies_released = pd.Series([7992,8721,8920,9443,9756,9820,9929,9955,8501]) 

# Create the Index 
index_ = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018] 
  
# set the index 
total_movies_released.index = index_

# %%
ax = sns.lineplot(total_movies_released.index, total_movies_released.values, color="#ff457a")
ax.set(xlabel='Year of Release', ylabel='Total Films')
ax.set_title("Movies Released Every Year")
ax.set_ylim(bottom = 0)
plt.show()

# %%
df_watched
# Out:
#                                              title  release_year  \
# 36              (DIS)HONESTY: THE TRUTH ABOUT LIES        2015.0
# 88                                               1        2013.0
# 99                                1 CHANCE 2 DANCE        2014.0
# 108                                  1 MILE TO YOU        2017.0
# 137                            10 CLOVERFIELD LANE        2016.0
# 170                                  10,000 SAINTS        2015.0
# 173                                10.0 EARTHQUAKE        2014.0
# 188                         100 DEGREES BELOW ZERO        2013.0
# 199                                    100 STREETS        2016.0
# 249                                          10X10        2018.0
# 262                                       11-11-11        2011.0
# 294                                   12 FEET DEEP        2017.0
# 311                          12 ROUNDS 2: RELOADED        2013.0
# 312                          12 ROUNDS 3: LOCKDOWN        2015.0
# 314                                      12 STRONG        2018.0
# 317                               12 YEARS A SLAVE        2013.0
# 331                                      127 HOURS        2010.0
# 335                                             13        2010.0
# 344                                       13 EERIE        2013.0
# 353                                        13 SINS        2014.0
# 379                                           13TH        2016.0
# 383                                      14 BLADES        2010.0
# 384                                     14 CAMERAS        2018.0
# 390                                            14+        2015.0
# 434                                       17 GIRLS        2011.0
# 448                        18 YEARS OLD AND RISING        2011.0
# 473                                           1911        2011.0
# 481                                           1922        2017.0
# 541                             2 DAYS IN NEW YORK        2012.0
# 555                                         2 GUNS        2013.0
# ...                                            ...           ...
# 84563                                    YOU AGAIN        2010.0
# 84566                                    YOU AND I        2011.0
# 84623                                   YOU GET ME        2017.0
# 84640                   YOU MAY NOT KISS THE BRIDE        2011.0
# 84642                      YOU MIGHT BE THE KILLER        2018.0
# 84650                          YOU SHALL NOT SLEEP        2018.0
# 84666           YOU WILL MEET A TALL DARK STRANGER        2010.0
# 84688                               YOU'RE NOT YOU        2014.0
# 84709                                  YOUNG ADULT        2011.0
# 84723  YOUNG DETECTIVE DEE: RISE OF THE SEA DRAGON        2013.0
# 84742                                   YOUNG ONES        2014.0
# 84771                                YOUR HIGHNESS        2011.0
# 84800                                        YOUTH        2015.0
# 84802                                        YOUTH        2017.0
# 84864                           YVES SAINT LAURENT        2014.0
# 84876                              Z FOR ZACHARIAH        2015.0
# 84918                                         ZAMA        2017.0
# 84921                                     ZAMBEZIA        2012.0
# 84936                                       ZARAFA        2012.0
# 84972                    ZEITGEIST: MOVING FORWARD        2011.0
# 85008                                ZERO CHARISMA        2013.0
# 85010                             ZERO DARK THIRTY        2012.0
# 85011                                    ZERO DAYS        2016.0
# 85018                              ZERO MOTIVATION        2014.0
# 85082                                       ZIPPER        2015.0
# 85161                              ZOMBIE MASSACRE        2013.0
# 85226                                    ZOOKEEPER        2011.0
# 85229                                  ZOOLANDER 2        2016.0
# 85236                                     ZOOMBIES        2016.0
# 85238                                     ZOOTOPIA        2016.0
#
#                            genres  averagerating  numvotes  \
# 36         Documentary,Drama,News            7.5    1831.0
# 88      Documentary,History,Sport            8.0    3452.0
# 99                   Drama,Family            4.9     486.0
# 108           Drama,Romance,Sport            6.3    1865.0
# 137          Drama,Horror,Mystery            7.2  260383.0
# 170            Comedy,Drama,Music            5.9    4938.0
# 173        Action,Adventure,Drama            3.5    1374.0
# 188        Action,Adventure,Drama            2.5    1798.0
# 199                         Drama            5.7    3338.0
# 249                      Thriller            5.0    5194.0
# 262       Horror,Mystery,Thriller            4.0   11712.0
# 294               Horror,Thriller            5.6   10731.0
# 311     Action,Adventure,Thriller            5.4    4895.0
# 312         Action,Crime,Thriller            5.3    3319.0
# 314          Action,Drama,History            6.6   50155.0
# 317       Biography,Drama,History            8.1  577301.0
# 331     Adventure,Biography,Drama            7.6  323949.0
# 335                Drama,Thriller            6.1   38418.0
# 344                 Horror,Sci-Fi            4.5    2453.0
# 353               Horror,Thriller            6.3   29550.0
# 379     Crime,Documentary,History            8.2   19507.0
# 383       Action,History,Thriller            6.4    7100.0
# 384            Crime,Drama,Horror            4.5    1646.0
# 390                 Drama,Romance            7.1    1183.0
# 434                         Drama            6.0    2980.0
# 448                Comedy,Romance            6.3     388.0
# 473        Action,Adventure,Drama            5.9    5534.0
# 481            Crime,Drama,Horror            6.3   37075.0
# 541          Comedy,Drama,Romance            6.0   13318.0
# 555           Action,Comedy,Crime            6.7  182025.0
# ...                           ...            ...       ...
# 84563       Comedy,Family,Romance            5.8   46690.0
# 84566               Drama,Romance            4.9    2094.0
# 84623         Crime,Drama,Romance            4.7    9524.0
# 84640         Action,Comedy,Crime            5.4    6220.0
# 84642       Comedy,Horror,Mystery            6.1    2337.0
# 84650     Horror,Mystery,Thriller            5.1     873.0
# 84666        Comedy,Drama,Romance            6.3   41608.0
# 84688                       Drama            7.4   22156.0
# 84709                Comedy,Drama            6.3   74071.0
# 84723      Action,Adventure,Drama            6.5    3944.0
# 84742        Action,Drama,Romance            5.9    8694.0
# 84771    Adventure,Comedy,Fantasy            5.5   92940.0
# 84800          Comedy,Drama,Music            7.3   64418.0
# 84802           Drama,Romance,War            7.1    2221.0
# 84864             Biography,Drama            6.2   10311.0
# 84876       Drama,Sci-Fi,Thriller            6.0   25429.0
# 84918                       Drama            6.8    3982.0
# 84921  Adventure,Animation,Comedy            5.8    6010.0
# 84936  Adventure,Animation,Family            7.0    1367.0
# 84972                 Documentary            8.2   16879.0
# 85008                Comedy,Drama            6.2    2371.0
# 85010              Drama,Thriller            7.4  251072.0
# 85011                 Documentary            7.8    7875.0
# 85018                Comedy,Drama            7.3    3645.0
# 85082              Drama,Thriller            5.8    6120.0
# 85161        Action,Horror,Sci-Fi            2.3    1642.0
# 85226       Comedy,Family,Romance            5.2   52396.0
# 85229                      Comedy            4.7   59914.0
# 85236     Action,Adventure,Comedy            3.4    1881.0
# 85238  Adventure,Animation,Comedy            8.0  383446.0
#
#                      genre_ids  popularity  vote_average  vote_count  \
# 36                        [99]       1.705           7.1        32.0
# 88                        [99]       6.013           7.4        53.0
# 99                          []       2.005           5.8        32.0
# 108                [18, 10749]       6.497           6.6       103.0
# 137              [53, 878, 18]      17.892           6.9      4629.0
# 170            [35, 18, 10402]       6.474           5.9        95.0
# 173               [18, 12, 28]       4.277           4.1        41.0
# 188                  [28, 878]       4.376           3.5        46.0
# 199                       [18]       7.317           6.2        91.0
# 249                   [53, 53]      13.334           5.2       218.0
# 262                   [27, 53]       5.196           4.3       116.0
# 294                   [53, 27]       9.742           5.3       184.0
# 311                   [28, 12]       7.606           5.5       146.0
# 312               [28, 53, 80]       6.925           5.0        68.0
# 314        [10752, 18, 36, 28]      13.183           5.6      1312.0
# 317                   [18, 36]      16.493           7.9      6631.0
# 331               [12, 18, 53]      11.435           7.0      4469.0
# 335                   [18, 53]       8.007           5.7       392.0
# 344                   [27, 53]       7.678           4.6        50.0
# 353                   [27, 53]      10.899           6.3       576.0
# 379                       [99]       5.746           8.1       271.0
# 383               [18, 28, 53]       7.948           6.6        87.0
# 384                   [27, 53]       6.153           5.5        27.0
# 390                [10749, 18]       4.598           7.2        35.0
# 434                       [18]       6.701           5.5       199.0
# 448                       [35]       4.391           5.3        33.0
# 473    [12, 18, 28, 36, 10752]       7.437           5.5        62.0
# 481     [80, 18, 27, 9648, 53]       9.467           5.9      1245.0
# 541            [35, 18, 10749]       7.385           5.6       149.0
# 555               [28, 35, 80]      14.800           6.5      2368.0
# ...                        ...         ...           ...         ...
# 84563              [35, 10749]      10.208           6.2       734.0
# 84566          [18, 53, 10749]       2.629           4.9        25.0
# 84623          [53, 10749, 18]       9.149           5.6      1167.0
# 84640      [28, 80, 35, 10749]       7.974           5.9        98.0
# 84642           [27, 35, 9648]       6.263           6.2        27.0
# 84650                 [27, 53]       7.249           5.1        58.0
# 84666          [35, 18, 10749]       6.209           5.8       431.0
# 84688                     [18]       6.874           7.4       448.0
# 84709                 [35, 18]       8.335           5.7       603.0
# 84723         [28, 80, 14, 12]       7.689           6.1       120.0
# 84742        [37, 28, 18, 878]       6.107           5.8       160.0
# 84771             [35, 12, 14]      12.254           5.3       735.0
# 84800                 [35, 18]       9.265           6.9      1098.0
# 84802                 [18, 36]       5.082           7.7        27.0
# 84864                     [18]       6.776           6.6       466.0
# 84876            [18, 878, 53]       9.464           5.6       471.0
# 84918                     [18]       5.671           6.9        50.0
# 84921      [35, 16, 12, 10751]       7.931           5.6       131.0
# 84936              [10751, 16]       2.705           6.8        39.0
# 84972                     [99]       9.150           7.1       104.0
# 85008                     [35]       1.815           6.6        25.0
# 85010             [53, 18, 36]      14.239           6.9      2553.0
# 85011                     [99]       6.689           7.5       111.0
# 85018                 [18, 35]       1.760           6.7        32.0
# 85082                 [53, 18]       9.373           5.7        85.0
# 85161                 [28, 27]       3.969           3.1        30.0
# 85226       [35, 10749, 10751]      10.764           5.3       886.0
# 85229                     [35]      12.997           4.7      1374.0
# 85236            [878, 28, 27]       5.916           3.9        47.0
# 85238      [16, 12, 10751, 35]      27.549           7.7      9977.0
#
#       release_year_month production_budget domestic_gross worldwide_gross  \
# 36               2015-05               NaN            NaN             NaN
# 88               2013-09               NaN            NaN             NaN
# 99               2014-01               NaN            NaN             NaN
# 108              2017-04               NaN            NaN             NaN
# 137              2016-03        $5,000,000    $72,082,999    $108,286,422
# 170              2015-08               NaN            NaN             NaN
# 173              2014-10               NaN            NaN             NaN
# 188              2013-04               NaN            NaN             NaN
# 199              2016-06               NaN            NaN             NaN
# 249              2018-04               NaN            NaN             NaN
# 262              2011-11               NaN            NaN             NaN
# 294              2017-06               NaN            NaN             NaN
# 311              2013-06               NaN            NaN             NaN
# 312              2015-09               NaN            NaN             NaN
# 314              2018-01       $35,000,000    $45,819,713     $71,118,378
# 317              2013-10       $20,000,000    $56,671,993    $181,025,343
# 331              2010-11       $18,000,000    $18,335,230     $60,217,171
# 335              2010-03               NaN            NaN             NaN
# 344              2013-04               NaN            NaN             NaN
# 353              2014-04        $4,000,000         $9,134         $47,552
# 379              2016-10               NaN            NaN             NaN
# 383              2010-02               NaN            NaN             NaN
# 384              2018-07               NaN            NaN             NaN
# 390              2015-11               NaN            NaN             NaN
# 434              2011-10               NaN            NaN             NaN
# 448              2011-11               NaN            NaN             NaN
# 473              2011-10               NaN            NaN             NaN
# 481              2017-10               NaN            NaN             NaN
# 541              2012-08               NaN            NaN             NaN
# 555              2013-08       $61,000,000    $75,612,460    $132,493,015
# ...                  ...               ...            ...             ...
# 84563            2010-09       $20,000,000    $25,702,053     $32,838,945
# 84566            2011-01               NaN            NaN             NaN
# 84623            2017-06               NaN            NaN             NaN
# 84640            2011-04               NaN            NaN             NaN
# 84642            2018-09               NaN            NaN             NaN
# 84650            2018-04               NaN            NaN             NaN
# 84666            2010-05               NaN            NaN             NaN
# 84688            2014-10               NaN            NaN             NaN
# 84709            2011-12       $12,000,000    $16,311,571     $22,750,356
# 84723            2013-09               NaN            NaN             NaN
# 84742            2014-10               NaN            NaN             NaN
# 84771            2011-04       $50,000,000    $21,596,445     $26,121,638
# 84800            2015-12       $13,000,000     $2,703,296     $24,001,573
# 84802            2017-12               NaN            NaN             NaN
# 84864            2014-06               NaN            NaN             NaN
# 84876            2015-08               NaN            NaN             NaN
# 84918            2017-09               NaN            NaN             NaN
# 84921            2012-07               NaN            NaN             NaN
# 84936            2012-11               NaN            NaN             NaN
# 84972            2011-01               NaN            NaN             NaN
# 85008            2013-10               NaN            NaN             NaN
# 85010            2012-12       $52,500,000    $95,720,716    $134,612,435
# 85011            2016-07               NaN            NaN             NaN
# 85018            2014-10               NaN            NaN             NaN
# 85082            2015-08        $4,500,000             $0              $0
# 85161            2013-08               NaN            NaN             NaN
# 85226            2011-07       $80,000,000    $80,360,866    $170,805,525
# 85229            2016-02       $50,000,000    $28,848,693     $55,348,693
# 85236            2016-05               NaN            NaN             NaN
# 85238            2016-03      $150,000,000   $341,268,248  $1,019,429,616
#
#       _merge month
# 36      both    05
# 88      both    09
# 99      both    01
# 108     both    04
# 137     both    03
# 170     both    08
# 173     both    10
# 188     both    04
# 199     both    06
# 249     both    04
# 262     both    11
# 294     both    06
# 311     both    06
# 312     both    09
# 314     both    01
# 317     both    10
# 331     both    11
# 335     both    03
# 344     both    04
# 353     both    04
# 379     both    10
# 383     both    02
# 384     both    07
# 390     both    11
# 434     both    10
# 448     both    11
# 473     both    10
# 481     both    10
# 541     both    08
# 555     both    08
# ...      ...   ...
# 84563   both    09
# 84566   both    01
# 84623   both    06
# 84640   both    04
# 84642   both    09
# 84650   both    04
# 84666   both    05
# 84688   both    10
# 84709   both    12
# 84723   both    09
# 84742   both    10
# 84771   both    04
# 84800   both    12
# 84802   both    12
# 84864   both    06
# 84876   both    08
# 84918   both    09
# 84921   both    07
# 84936   both    11
# 84972   both    01
# 85008   both    10
# 85010   both    12
# 85011   both    07
# 85018   both    10
# 85082   both    08
# 85161   both    08
# 85226   both    07
# 85229   both    02
# 85236   both    05
# 85238   both    03
#
# [3861 rows x 15 columns]

# %%
movie_genres_by_month = df_watched.groupby(['month'])['genres'].sum()

# %%
movie_genre = []
for items in movie_genres_by_month.iteritems():
    movie_genre.append(items[1].count("Horror")) 
movie_genre_mon = pd.Series(movie_genre) 
movie_genre_mon = movie_genre_mon.rename({0: "Jan", 1:"Feb", 2:"Mar", 3:"Apr",4:"May",5:"June",6:"July", 7:"Aug", 8:"Sep", 9:"Oct", 10:"Nov", 11:"Dec"})
print(sum(movie_genre_mon))


#Animation Total is 185
#Horror is 619
#Action is 894
#Documentary is 312
#Thriller is 733
#Romance 525
#Comedy 1225
#Sport 85
#Adventure 565
#Sci-287
# Out:
# 619

# %%
#Graph of genre_target by month
genresreleases = sns.barplot(movie_genre_mon.index, movie_genre_mon.values, color="#ff457a")
genresreleases.set(xlabel='Month of Release', ylabel='Total Films')
genresreleases.set_title("Animation Movies Released Per Month")
plt.show()

# %%
#sum of all the movies genres
genre_movies_released = pd.Series([185,619,894,312,733,525,1225,85,565,287,238,576,319,142,1908]) 

# Create the Index 
genre_movies_released_index_ = ["Animation", "Horror", "Action", "Documentary", "Thriller", "Romance", "Comedy", "Sport", "Adventure", "Sci-Fi", "Fantasy", "Crime", "Biography", "Music", "Drama"] 
  
# set the index 
genre_movies_released.index = genre_movies_released_index_

# %%
#Graph of genre_target 
genresreleasestotal = sns.barplot(genre_movies_released.index, genre_movies_released.values, color="#ff457a")
genresreleasestotal.set(xlabel='Genre', ylabel='Total Films')
plt.xticks(rotation=90)
# ax.set_ylim(top=1600)
plt.show()

# %%
sum(df_watched["month"].value_counts())
# Out:
# 3861

# %%
total_movies_month = df_watched["month"].value_counts()

# %%
total_movies_month = total_movies_month.sort_index()

# %%
#Renaming X-Axis for legibility
total_movies_month = total_movies_month.rename({"01": "Jan", "02": "Feb", "03": "Mar", "04": "Apr", "05":"May", "06":"June", "07":"July","08":"Aug", "09": "Sep", "10":"Oct", "11":"Nov", "12":"Dec"})

# %%
ax = sns.barplot(total_movies_month.index, total_movies_month.values, color="#ff457a")
ax.set(xlabel='Month of Release', ylabel='Total Films')
ax.set_title("Well-Attended Movies Released Per Month")
plt.show()

# %%
p1=sns.boxplot(x=df_watched["month"], y=df_watched["averagerating"], data=df_watched, order=["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], color="steelblue")

# %%
p1=sns.boxplot(x=df_watched["month"], y=df_watched["vote_average"], data=df_watched, order=["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], color="steelblue")

# %%
df_watched["genres"].unique()
# Out:
# array(['Documentary,Drama,News', 'Documentary,History,Sport',
#        'Drama,Family', 'Drama,Romance,Sport', 'Drama,Horror,Mystery',
#        'Comedy,Drama,Music', 'Action,Adventure,Drama', 'Drama',
#        'Thriller', 'Horror,Mystery,Thriller', 'Horror,Thriller',
#        'Action,Adventure,Thriller', 'Action,Crime,Thriller',
#        'Action,Drama,History', 'Biography,Drama,History',
#        'Adventure,Biography,Drama', 'Drama,Thriller', 'Horror,Sci-Fi',
#        'Crime,Documentary,History', 'Action,History,Thriller',
#        'Crime,Drama,Horror', 'Drama,Romance', 'Comedy,Romance',
#        'Comedy,Drama,Romance', 'Action,Comedy,Crime', 'Action,Sci-Fi',
#        'Documentary,Music', 'Documentary,Drama,Music', 'Comedy,Horror',
#        'Documentary', 'Action,Sci-Fi,Thriller', 'Comedy,Drama', 'Comedy',
#        'Action,Crime,Drama', 'Crime,Drama,History', 'Drama,Family,Sport',
#        'Action,Drama,Thriller', 'Comedy,Family', 'Action,Fantasy,War',
#        'Biography,Crime,Drama', 'Drama,Sport', 'Action,Adventure,Sci-Fi',
#        'Biography,Drama,Sport', 'Adventure,Drama,Horror',
#        'Action,Thriller,Western', 'Action,Drama,War',
#        'Comedy,Crime,Romance', 'Horror', 'Crime,Drama,Thriller',
#        'Action,Thriller', 'Action,Drama', 'Adventure,Comedy',
#        'Adventure,Comedy,Drama', 'Fantasy,Horror,Mystery',
#        'Biography,Drama,Romance', 'Comedy,Drama,Family',
#        'Biography,Comedy', 'Drama,Fantasy,Romance', 'Drama,Horror',
#        'Comedy,Fantasy', 'Drama,Horror,Thriller', 'Drama,Music',
#        'Comedy,Drama,Fantasy', 'Adventure,Crime,Thriller',
#        'Comedy,Western', 'Animation,Drama,Fantasy',
#        'Adventure,Animation,Comedy', 'Biography,Drama,War',
#        'Drama,Horror,Sci-Fi', 'Comedy,Crime,Drama', 'Drama,Music,Romance',
#        'Biography,Comedy,Drama', 'Biography,Family',
#        'Adventure,Biography,Comedy', 'Action,Drama,Family',
#        'Adventure,Family,Fantasy', 'Action,Adventure,Family',
#        'Crime,Documentary', 'Action,Fantasy,Horror', 'Comedy,Sci-Fi',
#        'Comedy,Crime', 'Romance', 'Drama,Romance,Thriller',
#        'Action,Crime', 'Action,Adventure,Biography',
#        'Drama,Family,Sci-Fi', 'Drama,Music,Musical',
#        'Adventure,Documentary', 'Action,Adventure,Fantasy',
#        'Drama,History', 'Crime,Drama,Romance', 'Drama,Sci-Fi,Thriller',
#        'Action,Adventure,Comedy', 'Action,Crime,Mystery',
#        'Drama,Romance,War', 'Horror,Sci-Fi,Thriller',
#        'Action,Comedy,Fantasy', 'Documentary,News',
#        'Comedy,Fantasy,Horror', 'Biography,Drama,Music',
#        'Action,Adventure,Horror', 'Crime,Drama,Mystery', 'Action',
#        'Action,Adventure,Mystery', 'Action,Drama,Romance',
#        'Action,Drama,Fantasy', 'Adventure,Drama,Family',
#        'Horror,Mystery,Sci-Fi', 'Crime,Horror,Mystery',
#        'Action,Comedy,Drama', 'Adventure,Drama,Romance', 'Crime,Drama',
#        'Action,Biography,Comedy', 'Drama,Music,Thriller',
#        'Action,Biography,Drama', 'Action,Comedy,Sci-Fi',
#        'Biography,Comedy,Documentary', 'Drama,Mystery',
#        'Adventure,Comedy,Sci-Fi', 'Comedy,Drama,Musical',
#        'Animation,Comedy,Drama', 'Sci-Fi,Thriller',
#        'Drama,Romance,Sci-Fi', 'Adventure,Biography,Documentary',
#        'Adventure,Comedy,Family', 'Biography,History,Thriller',
#        'Drama,Fantasy,Horror', 'Action,Animation,Sci-Fi', 'Action,War',
#        'Biography,Drama,Thriller', 'Comedy,Thriller',
#        'Action,Horror,Thriller', 'Drama,Mystery,Sci-Fi', 'Fantasy',
#        'Adventure,Animation,Family', 'Adventure,Horror,Mystery',
#        'Drama,Sci-Fi', 'Drama,Sport,Thriller', 'Biography,Drama',
#        'Crime,Thriller', 'Action,Mystery,Thriller',
#        'Action,Comedy,Horror', 'Comedy,Horror,Mystery',
#        'Action,Horror,Mystery', 'Documentary,Family,History',
#        'Drama,History,Romance', 'Comedy,Fantasy,Romance',
#        'Comedy,Mystery,Thriller', 'Action,Comedy,Thriller',
#        'Adventure,Comedy,Crime', 'Crime,Horror,Thriller',
#        'Documentary,Music,Sport', 'Documentary,History,News',
#        'Animation,Family', 'Animation,Family,Sci-Fi',
#        'Animation,Family,Musical', 'Animation,Documentary,Mystery',
#        'Action,Adventure,Animation', 'Action,Animation',
#        'Action,Animation,Crime', 'Biography,Documentary,Drama',
#        'Drama,War', 'Adventure,Drama,Fantasy', 'Family,Fantasy,Musical',
#        'Drama,Fantasy,Mystery', 'Drama,Musical,Romance',
#        'Crime,Drama,Family', 'Comedy,Drama,Thriller',
#        'Comedy,Crime,Horror', 'Drama,Fantasy,Thriller',
#        'Biography,Crime,Documentary', 'Adventure,Horror',
#        'Mystery,Sci-Fi,Thriller', 'Biography,Drama,Family',
#        'Comedy,Horror,Thriller', 'Mystery,Thriller', 'Drama,Family,Music',
#        'Documentary,Drama', 'Action,Adventure,Western',
#        'Action,Animation,Drama', 'Drama,Fantasy', 'Comedy,Sport',
#        'Horror,Mystery', 'Biography,Documentary,History',
#        'Action,Comedy,Romance', 'Comedy,Drama,Horror',
#        'Drama,Mystery,Thriller', 'Drama,Thriller,War',
#        'Drama,History,Thriller', 'Action,Crime,Fantasy',
#        'Comedy,Romance,Sport', 'Action,Adventure',
#        'Biography,Comedy,Crime', 'Action,Animation,Comedy',
#        'Action,Crime,Horror', 'Action,Comedy',
#        'Documentary,Drama,Mystery', 'Action,Comedy,Family',
#        'Documentary,History', 'Action,Drama,Horror',
#        'Biography,Documentary', 'Comedy,Musical',
#        'Adventure,Animation,Drama', 'Biography,Documentary,Thriller',
#        'Action,Drama,Mystery', 'Animation,Biography,Documentary',
#        'Comedy,Documentary,Music', 'Biography,Documentary,Sport',
#        'Comedy,Romance,Thriller', 'Comedy,War', 'Comedy,Drama,Western',
#        'Adventure,Comedy,Horror', 'Western', 'Action,Horror,Sci-Fi',
#        'Comedy,Horror,Western', 'Action,Horror', 'Adventure,Crime,Drama',
#        'Animation,Drama', 'Animation,Comedy,Family',
#        'Drama,Mystery,Romance', 'Adventure,Family,Sci-Fi',
#        'Action,Drama,Sport', 'Crime,Documentary,Drama', 'Drama,Western',
#        'Fantasy,Horror,Thriller', 'Action,Crime,Sci-Fi',
#        'Action,Fantasy,Thriller', 'Documentary,Family', 'Comedy,History',
#        'Action,Drama,Sci-Fi', 'Thriller,War', 'Drama,Fantasy,Sci-Fi',
#        'Crime,Mystery,Thriller', 'Comedy,Crime,Documentary',
#        'Action,Adventure,Crime', 'Adventure,Drama,Mystery',
#        'Documentary,Sport', 'Animation,Drama,Romance',
#        'Comedy,Crime,Mystery', 'Drama,History,War',
#        'Comedy,Horror,Sci-Fi', 'Comedy,Crime,Thriller',
#        'Action,Documentary', 'Drama,Thriller,Western',
#        'Documentary,Drama,Sport', 'Comedy,Drama,Sci-Fi',
#        'Biography,Documentary,Music', 'Adventure,Comedy,Music',
#        'Animation,Drama,History', 'Action,History',
#        'Adventure,Drama,Thriller', 'Biography,Family,Sport',
#        'Comedy,Drama,Sport', 'Action,Adventure,History', 'Comedy,Mystery',
#        'Documentary,Drama,Family', 'Horror,Western',
#        'Adventure,Fantasy,Mystery', 'Biography', 'Horror,Mystery,Romance',
#        'Comedy,Music', 'Action,Comedy,Sport', 'Documentary,Family,Music',
#        'Animation,Comedy,Crime', 'Fantasy,Horror',
#        'Adventure,Drama,Western', 'Comedy,Mystery,Sci-Fi',
#        'Action,Comedy,Musical', 'Romance,Sci-Fi,Thriller',
#        'Adventure,Fantasy,Romance', 'Fantasy,Thriller',
#        'Drama,Horror,Romance', 'Action,Comedy,History',
#        'Drama,Fantasy,Music', 'Drama,Mystery,War',
#        'Adventure,Drama,Sci-Fi', 'Animation,Documentary',
#        'Action,Biography,Crime', 'Action,Fantasy', 'Adventure,Fantasy',
#        'Action,Comedy,Documentary', 'Family', 'Adventure,Comedy,Fantasy',
#        'Comedy,Mystery,Romance', 'Comedy,Documentary', 'Adventure,Drama',
#        'Action,Family', 'Documentary,History,War', 'Comedy,Drama,War',
#        'Documentary,War', 'Drama,History,Musical',
#        'Comedy,Documentary,Drama', 'Adventure,Documentary,Drama',
#        'Adventure,Family,Mystery', 'Drama,Music,Sci-Fi', 'Drama,Musical',
#        'Animation,Biography,Crime', 'Comedy,Musical,Romance',
#        'Biography,Documentary,Fantasy', 'Comedy,Family,Fantasy',
#        'Comedy,Drama,Mystery', 'Comedy,Family,Romance',
#        'Action,Adventure,Documentary', 'Adventure,Comedy,Romance',
#        'Biography,Documentary,Family', 'Animation,Fantasy',
#        'Comedy,Documentary,Musical', 'Biography,Drama,Horror',
#        'Comedy,Horror,Romance', 'Mystery,Romance,Thriller',
#        'Adventure,Documentary,Family', 'Crime,Mystery,Sci-Fi',
#        'Fantasy,Mystery,Romance', 'Drama,History,Mystery',
#        'Comedy,Music,Romance', 'Action,Crime,Sport',
#        'Adventure,Mystery,Sci-Fi', 'Adventure,Fantasy,Horror',
#        'Documentary,Horror', 'Thriller,Western',
#        'Biography,Documentary,News', 'Action,Animation,Horror',
#        'Action,Sci-Fi,War', 'Comedy,Music,War', 'Adventure,Family',
#        'Animation,Family,Fantasy', 'Action,Mystery,Sci-Fi',
#        'Crime,Romance,Thriller', 'Adventure,Drama,History',
#        'Comedy,Crime,Fantasy', 'Adventure,Western',
#        'Comedy,Fantasy,Sci-Fi', 'Horror,Romance,Sci-Fi',
#        'Comedy,Horror,Musical', 'Animation,Drama,Thriller',
#        'Adventure,Documentary,Sport', 'Action,Drama,Western',
#        'Adventure,Documentary,History', 'Biography,Horror',
#        'Animation,Drama,Family', 'Drama,Family,History', 'Horror,Musical',
#        'Biography,Drama,Musical', 'Crime,Documentary,Mystery',
#        'Crime,Drama,Fantasy', 'Comedy,Music,Sci-Fi',
#        'Adventure,Horror,Sci-Fi', 'Family,Fantasy', 'History,Thriller',
#        'Romance,Thriller', 'Action,Biography,Thriller',
#        'Comedy,Drama,History', 'Biography,Drama,Mystery',
#        'Action,Family,Fantasy', 'Drama,Fantasy,History', 'Crime',
#        'Comedy,Documentary,History', 'Action,Fantasy,Romance',
#        'Action,Adventure,Romance', 'Biography,Documentary,Mystery',
#        'Action,Fantasy,Western', 'Documentary,Mystery',
#        'Drama,Family,Fantasy', 'Animation,Crime,Documentary',
#        'Action,Western', 'Action,Animation,Fantasy',
#        'Drama,History,Sport', 'Animation,Documentary,History',
#        'Animation,Fantasy,Horror', 'Adventure,Animation',
#        'Crime,Drama,Western', 'Biography,Drama,Fantasy'], dtype=object)
